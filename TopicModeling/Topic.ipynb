# %%
import logging
import glob
import argparse
from gensim import models
from gensim import matutils
from sklearn.feature_extraction.text import TfidfVectorizer
from time import time
from nltk import bigrams
from nltk.tokenize import sent_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer
from gensim import corpora
from stop_words import get_stop_words
from collections import Counter
from itertools import product, compress
from collections import defaultdict
import math
import pandas as pd

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# Preprocessing the sample review text data and apply LDA model to get topics.

# %%
def preprocess(line):
    split = line.split()
    stemmer = SnowballStemmer("english")
    split = [stemmer.stem(w) for w in split]
    return ' '.join(split)

# %%
def topics(text, output_file, num_topic, num_display_word):
    vectorizer = TfidfVectorizer(max_df=0.9, 
                                 min_df=0.1, 
                                 stop_words='english', 
                                 preprocessor = preprocess,
                                 use_idf=True)
    
    #with open(input_file, 'r', encoding = 'utf-8') as f:
     #   text = f.readlines()
    
    print("Extracting features from the training dataset using a sparse vectorizer")
    X = vectorizer.fit_transform(text)
    print("n_samples: %d, n_features: %d" % X.shape)
    
    # mapping from feature id to actual word
    id2words = {}
    for i, word in enumerate(vectorizer.get_feature_names()):
        id2words[i] = word
    
    print("Applying topic modeling, using LDA")
    print(str(num_topic) + " topics")
    corpus = matutils.Sparse2Corpus(X, documents_columns=False)
    lda = models.ldamodel.LdaModel(corpus, num_topics=num_topic, id2word=id2words)
    
    output_text = []
    output_text.append(['Topic'])
    for i, item in lda.show_topics(num_topics =num_topic, num_words=num_display_word, formatted=False):
        output_text.append(["Topic.Topic" + str(i)])
        for term, weight in item:
            output_text.append(["Topic." + "Topic" + str(i) + "." + term, str(weight)])
    df = pandas.DataFrame(output_text, columns = ['id', 'value'])
    print("writing topics to file:", output_file)
    df.to_csv(output_file, index = False)

# %%
topics('../listDes.txt','topics.csv', 10, 15)
# Out:
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 3818, n_features: 68
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: topics.csv

# %%
keywordToListId = pd.read_csv('data/keywordToListId.csv')
des = pd.read_csv("../data/listings.csv")

# %%
for index, row in keywordToListId.iterrows():
    ids = row.listid.replace('[', '').replace(']', '').split(', ');
    ids = [int(x) for x in ids]
    text = des.ix[ids].space
    topics(text, 'data/topicForKeyword/'+row.keyword+'.csv', 10, 15)
# Out:
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 238, n_features: 125
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/capitol hill.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 209, n_features: 146
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/downtown seattle.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 160, n_features: 159
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/space needle.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 132, n_features: 173
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/wireless internet.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 124, n_features: 170
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/lake union.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 123, n_features: 139
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/bus stop.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 106, n_features: 141
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/puget sound.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 101, n_features: 122
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/lake washington.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 99, n_features: 138
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/light rail.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 98, n_features: 110
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/air mattress.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 98, n_features: 146
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/wi fi.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 97, n_features: 162
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/hair dryer.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 87, n_features: 179
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/sleeper sofa.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 86, n_features: 117
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/hardwood floors.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 85, n_features: 145
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/floor plan.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 84, n_features: 165
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/dvd player.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 81, n_features: 154
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/stainless steel.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 78, n_features: 135
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/lower level.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 71, n_features: 139
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/open floor plan.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 68, n_features: 167
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/gas stove.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 66, n_features: 151
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/short walk.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 64, n_features: 160
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/south lake union.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 63, n_features: 160
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/hot tub.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 57, n_features: 161
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/shampoo conditioner.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 55, n_features: 130
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/green lake.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 50, n_features: 196
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/bunk bed.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 49, n_features: 190
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/walk score.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 47, n_features: 162
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/rooftop deck.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 42, n_features: 147
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/bus lines.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 40, n_features: 188
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/queen anne.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 40, n_features: 153
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/ground floor.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 39, n_features: 184
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/hot water.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 38, n_features: 178
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/gas fireplace.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 37, n_features: 194
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/sofa sleeper.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 37, n_features: 178
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/radiant heat.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 36, n_features: 189
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/alki beach.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 35, n_features: 167
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/gas range.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 34, n_features: 176
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/woodland park zoo.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 33, n_features: 200
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/public transit.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 33, n_features: 151
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/smart tv.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 30, n_features: 200
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/gas grill.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 30, n_features: 194
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/west seattle.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 29, n_features: 224
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/long term.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 29, n_features: 176
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/wood floors.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 28, n_features: 213
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/amazon prime.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 28, n_features: 179
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/claw foot tub.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 27, n_features: 173
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/safeco field.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 26, n_features: 173
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/french press.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 25, n_features: 157
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/ground level.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 25, n_features: 171
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/pioneer square.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 23, n_features: 173
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/seward park.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 23, n_features: 150
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/elliott bay.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 22, n_features: 179
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/open concept.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 21, n_features: 136
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/public transportation.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 21, n_features: 149
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/seatac airport.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 21, n_features: 134
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/air conditioning.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 21, n_features: 187
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/blu ray.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 20, n_features: 281
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/basic cable.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 20, n_features: 308
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/mount rainier.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 20, n_features: 271
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/elliot bay.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 19, n_features: 201
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/flatscreen tv.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 19, n_features: 214
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/interior designer.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 19, n_features: 218
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/surround sound.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 19, n_features: 262
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/burke gilman trail.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 19, n_features: 208
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/craftsman style.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 18, n_features: 177
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/beacon hill.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 18, n_features: 210
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/cal anderson park.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 18, n_features: 244
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/central district.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 17, n_features: 208
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/link light rail.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 17, n_features: 204
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/upper level.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 17, n_features: 228
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/columbia city.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 17, n_features: 252
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/ice cream.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 17, n_features: 249
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/leather sofa.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 16, n_features: 174
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/prime location.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 16, n_features: 190
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/music venues.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 15, n_features: 253
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/art galleries.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 15, n_features: 216
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/fresh air.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 15, n_features: 190
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/open plan.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 14, n_features: 168
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/french doors.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 13, n_features: 161
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/hd tv.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 12, n_features: 113
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/basement apartment.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 11, n_features: 151
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/express bus.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 11, n_features: 130
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/thread count sheets.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 10, n_features: 426
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/emerald city.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 10, n_features: 441
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/bus stops.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 8, n_features: 383
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/board games.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 8, n_features: 412
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/bunk beds.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 8, n_features: 380
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/pike pine.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 7, n_features: 114
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/tech scene.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 6, n_features: 279
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/major bus routes.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 5, n_features: 259
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/microwave oven.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 5, n_features: 269
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/coffee maker.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 5, n_features: 145
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/keyless entry.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 4, n_features: 211
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/studio apartment.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 4, n_features: 194
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/cable tv.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 3, n_features: 184
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/square foot.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 3, n_features: 113
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/memory foam.csv
# Extracting features from the training dataset using a sparse vectorizer
# n_samples: 2, n_features: 120
# Applying topic modeling, using LDA
# 10 topics
# writing topics to file: data/topicForKeyword/pike pine corridor.csv
